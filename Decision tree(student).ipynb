# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv(r"C:\Users\Omkar Pawar\Downloads\xAPI-Edu-Data.csv")
data
# Out:
#     gender       StageID SectionID Relation Semester      Topic  raisedhands  \
# 0        M    lowerlevel         A   Father        F         IT           15
# 1        M    lowerlevel         A   Father        F         IT           20
# 2        M    lowerlevel         A   Father        F         IT           10
# 3        M    lowerlevel         A   Father        F         IT           30
# 4        M    lowerlevel         A   Father        F         IT           40
# ..     ...           ...       ...      ...      ...        ...          ...
# 475      F  MiddleSchool         A   Father        S  Chemistry            5
# 476      F  MiddleSchool         A   Father        F    Geology           50
# 477      F  MiddleSchool         A   Father        S    Geology           55
# 478      F  MiddleSchool         A   Father        F    History           30
# 479      F  MiddleSchool         A   Father        S    History           35
#
#      VisITedResources  AnnouncementsView  Discussion ParentschoolSatisfaction  \
# 0                  16                  2          20                     Good
# 1                  20                  3          25                     Good
# 2                   7                  0          30                      Bad
# 3                  25                  5          35                      Bad
# 4                  50                 12          50                      Bad
# ..                ...                ...         ...                      ...
# 475                 4                  5           8                      Bad
# 476                77                 14          28                      Bad
# 477                74                 25          29                      Bad
# 478                17                 14          57                      Bad
# 479                14                 23          62                      Bad
#
#     StudentAbsenceDays Class
# 0              Under-7     M
# 1              Under-7     M
# 2              Above-7     L
# 3              Above-7     L
# 4              Above-7     M
# ..                 ...   ...
# 475            Above-7     L
# 476            Under-7     M
# 477            Under-7     M
# 478            Above-7     L
# 479            Above-7     L
#
# [480 rows x 13 columns]

# %%
data.describe(include="all")
# Out:
#        gender       StageID SectionID Relation Semester Topic  raisedhands  \
# count     480           480       480      480      480   480   480.000000
# unique      2             3         3        2        2    12          NaN
# top         M  MiddleSchool         A   Father        F    IT          NaN
# freq      305           248       283      283      245    95          NaN
# mean      NaN           NaN       NaN      NaN      NaN   NaN    46.775000
# std       NaN           NaN       NaN      NaN      NaN   NaN    30.779223
# min       NaN           NaN       NaN      NaN      NaN   NaN     0.000000
# 25%       NaN           NaN       NaN      NaN      NaN   NaN    15.750000
# 50%       NaN           NaN       NaN      NaN      NaN   NaN    50.000000
# 75%       NaN           NaN       NaN      NaN      NaN   NaN    75.000000
# max       NaN           NaN       NaN      NaN      NaN   NaN   100.000000
#
#         VisITedResources  AnnouncementsView  Discussion  \
# count         480.000000         480.000000  480.000000
# unique               NaN                NaN         NaN
# top                  NaN                NaN         NaN
# freq                 NaN                NaN         NaN
# mean           54.797917          37.918750   43.283333
# std            33.080007          26.611244   27.637735
# min             0.000000           0.000000    1.000000
# 25%            20.000000          14.000000   20.000000
# 50%            65.000000          33.000000   39.000000
# 75%            84.000000          58.000000   70.000000
# max            99.000000          98.000000   99.000000
#
#        ParentschoolSatisfaction StudentAbsenceDays Class
# count                       480                480   480
# unique                        2                  2     3
# top                        Good            Under-7     M
# freq                        292                289   211
# mean                        NaN                NaN   NaN
# std                         NaN                NaN   NaN
# min                         NaN                NaN   NaN
# 25%                         NaN                NaN   NaN
# 50%                         NaN                NaN   NaN
# 75%                         NaN                NaN   NaN
# max                         NaN                NaN   NaN

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 480 entries, 0 to 479
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   gender                    480 non-null    object
#  1   StageID                   480 non-null    object
#  2   SectionID                 480 non-null    object
#  3   Relation                  480 non-null    object
#  4   Semester                  480 non-null    object
#  5   Topic                     480 non-null    object
#  6   raisedhands               480 non-null    int64
#  7   VisITedResources          480 non-null    int64
#  8   AnnouncementsView         480 non-null    int64
#  9   Discussion                480 non-null    int64
#  10  ParentschoolSatisfaction  480 non-null    object
#  11  StudentAbsenceDays        480 non-null    object
#  12  Class                     480 non-null    object
# dtypes: int64(4), object(9)
# memory usage: 48.9+ KB

# %%
data.isnull().sum()
# Out:
# gender                      0
# StageID                     0
# SectionID                   0
# Relation                    0
# Semester                    0
# Topic                       0
# raisedhands                 0
# VisITedResources            0
# AnnouncementsView           0
# Discussion                  0
# ParentschoolSatisfaction    0
# StudentAbsenceDays          0
# Class                       0
# dtype: int64

# %%
for i in data.columns:
    print({i:data[i].unique()})
# Out:
# {'gender': array(['M', 'F'], dtype=object)}
# {'StageID': array(['lowerlevel', 'MiddleSchool', 'HighSchool'], dtype=object)}
# {'SectionID': array(['A', 'B', 'C'], dtype=object)}
# {'Relation': array(['Father', 'Mum'], dtype=object)}
# {'Semester': array(['F', 'S'], dtype=object)}
# {'Topic': array(['IT', 'Math', 'Arabic', 'Science', 'English', 'Quran', 'Spanish',
#        'French', 'History', 'Biology', 'Chemistry', 'Geology'],
#       dtype=object)}
# {'raisedhands': array([ 15,  20,  10,  30,  40,  42,  35,  50,  12,  70,  19,   5,  62,
#         36,  55,  69,  60,   2,   0,   8,  25,  75,   4,  45,  14,  33,
#          7,  13,  29,  39,  49,  16,  28,  27,  21,  80,  17,  65,  22,
#         11,   1,   3, 100,   6,  90,  77,  24,  66,  23,  82,  72,  51,
#         85,  87,  95,  81,  53,  92,  83,  67,  96,  57,  73,   9,  32,
#         52,  59,  61,  79,  18,  74,  97,  41,  71,  98,  78,  89,  88,
#         86,  76,  99,  84])}
# {'VisITedResources': array([16, 20,  7, 25, 50, 30, 12, 10, 21, 80, 88,  6,  1, 14, 70, 40, 13,
#        15, 60,  0,  2, 19, 85, 90,  5, 22, 11, 54, 35, 33,  4, 39, 75, 69,
#         3,  8, 89, 44, 92, 26, 27, 29, 98,  9, 42, 65, 79, 55, 63, 91, 51,
#        58, 68, 82, 72, 52, 62, 71, 66, 43, 95, 31, 41, 81, 61, 83, 84, 17,
#        94, 48, 86, 74, 76, 97, 87, 99, 34, 64, 28, 38, 36, 24, 59, 57, 77,
#        18, 93, 96, 78])}
# {'AnnouncementsView': array([ 2,  3,  0,  5, 12, 13, 15, 16, 25, 30, 19, 44, 22, 20, 35, 36, 40,
#        33,  4, 52, 50, 10,  9,  8, 17, 26, 37,  7, 28,  1, 39,  6, 32, 70,
#        18, 23, 11, 29, 49, 55, 38, 41, 51, 95, 85, 71, 98, 73, 48, 58, 93,
#        83, 53, 63, 62, 82, 72, 42, 46, 77, 21, 88, 66, 86, 80, 56, 91, 65,
#        76, 24, 74, 59, 79, 34, 69, 89, 31, 60, 54, 57, 64, 87, 75, 67, 43,
#        45, 14, 78])}
# {'Discussion': array([20, 25, 30, 35, 50, 70, 17, 22, 80, 12, 11, 19, 60, 66, 90, 96, 99,
#        40, 33, 43, 16,  4, 88, 77, 75,  1,  5,  2,  8, 13, 44,  9, 55, 10,
#        15,  7,  3, 14, 69, 59, 89, 41, 91, 49, 73, 23, 53, 93, 51, 83, 24,
#        84, 61, 94, 34, 81, 29, 46, 26,  6, 76, 86, 85, 65, 95, 64, 32, 37,
#        36, 27, 39, 74, 79, 21, 31, 28, 38, 48, 97, 98, 63, 72, 82, 71, 45,
#        68, 92, 58, 57, 62])}
# {'ParentschoolSatisfaction': array(['Good', 'Bad'], dtype=object)}
# {'StudentAbsenceDays': array(['Under-7', 'Above-7'], dtype=object)}
# {'Class': array(['M', 'L', 'H'], dtype=object)}

# %%
data.Topic.value_counts()
# Out:
# Topic
# IT           95
# French       65
# Arabic       59
# Science      51
# English      45
# Biology      30
# Spanish      25
# Geology      24
# Chemistry    24
# Quran        22
# Math         21
# History      19
# Name: count, dtype: int64

# %%
data["Institute"] = "XYZ"
data
# Out:
#     gender       StageID SectionID Relation Semester      Topic  raisedhands  \
# 0        M    lowerlevel         A   Father        F         IT           15
# 1        M    lowerlevel         A   Father        F         IT           20
# 2        M    lowerlevel         A   Father        F         IT           10
# 3        M    lowerlevel         A   Father        F         IT           30
# 4        M    lowerlevel         A   Father        F         IT           40
# ..     ...           ...       ...      ...      ...        ...          ...
# 475      F  MiddleSchool         A   Father        S  Chemistry            5
# 476      F  MiddleSchool         A   Father        F    Geology           50
# 477      F  MiddleSchool         A   Father        S    Geology           55
# 478      F  MiddleSchool         A   Father        F    History           30
# 479      F  MiddleSchool         A   Father        S    History           35
#
#      VisITedResources  AnnouncementsView  Discussion ParentschoolSatisfaction  \
# 0                  16                  2          20                     Good
# 1                  20                  3          25                     Good
# 2                   7                  0          30                      Bad
# 3                  25                  5          35                      Bad
# 4                  50                 12          50                      Bad
# ..                ...                ...         ...                      ...
# 475                 4                  5           8                      Bad
# 476                77                 14          28                      Bad
# 477                74                 25          29                      Bad
# 478                17                 14          57                      Bad
# 479                14                 23          62                      Bad
#
#     StudentAbsenceDays Class Institute
# 0              Under-7     M       XYZ
# 1              Under-7     M       XYZ
# 2              Above-7     L       XYZ
# 3              Above-7     L       XYZ
# 4              Above-7     M       XYZ
# ..                 ...   ...       ...
# 475            Above-7     L       XYZ
# 476            Under-7     M       XYZ
# 477            Under-7     M       XYZ
# 478            Above-7     L       XYZ
# 479            Above-7     L       XYZ
#
# [480 rows x 14 columns]

# %%
data.columns
# Out:
# Index(['gender', 'StageID', 'SectionID', 'Relation', 'Semester', 'Topic',
#        'raisedhands', 'VisITedResources', 'AnnouncementsView', 'Discussion',
#        'ParentschoolSatisfaction', 'StudentAbsenceDays', 'Class', 'Institute'],
#       dtype='object')

# %%
# dropping institute columns as itt has singularity
data.drop(["Institute"],axis=1,inplace=True)

# %%
data
# Out:
#     gender       StageID SectionID Relation Semester      Topic  raisedhands  \
# 0        M    lowerlevel         A   Father        F         IT           15
# 1        M    lowerlevel         A   Father        F         IT           20
# 2        M    lowerlevel         A   Father        F         IT           10
# 3        M    lowerlevel         A   Father        F         IT           30
# 4        M    lowerlevel         A   Father        F         IT           40
# ..     ...           ...       ...      ...      ...        ...          ...
# 475      F  MiddleSchool         A   Father        S  Chemistry            5
# 476      F  MiddleSchool         A   Father        F    Geology           50
# 477      F  MiddleSchool         A   Father        S    Geology           55
# 478      F  MiddleSchool         A   Father        F    History           30
# 479      F  MiddleSchool         A   Father        S    History           35
#
#      VisITedResources  AnnouncementsView  Discussion ParentschoolSatisfaction  \
# 0                  16                  2          20                     Good
# 1                  20                  3          25                     Good
# 2                   7                  0          30                      Bad
# 3                  25                  5          35                      Bad
# 4                  50                 12          50                      Bad
# ..                ...                ...         ...                      ...
# 475                 4                  5           8                      Bad
# 476                77                 14          28                      Bad
# 477                74                 25          29                      Bad
# 478                17                 14          57                      Bad
# 479                14                 23          62                      Bad
#
#     StudentAbsenceDays Class
# 0              Under-7     M
# 1              Under-7     M
# 2              Above-7     L
# 3              Above-7     L
# 4              Above-7     M
# ..                 ...   ...
# 475            Above-7     L
# 476            Under-7     M
# 477            Under-7     M
# 478            Above-7     L
# 479            Above-7     L
#
# [480 rows x 13 columns]

# %%
# dropping "Secion ID", "Semester" based on domain knowledge
data.drop(["SectionID","Semester"],axis=1,inplace=True)

# %%
# Dropping feature "Topic" on the basis of domain knowledge & high cardinality
data.drop("Topic",axis=1,inplace=True)

# %%
data
# Out:
#     gender       StageID Relation  raisedhands  VisITedResources  \
# 0        M    lowerlevel   Father           15                16
# 1        M    lowerlevel   Father           20                20
# 2        M    lowerlevel   Father           10                 7
# 3        M    lowerlevel   Father           30                25
# 4        M    lowerlevel   Father           40                50
# ..     ...           ...      ...          ...               ...
# 475      F  MiddleSchool   Father            5                 4
# 476      F  MiddleSchool   Father           50                77
# 477      F  MiddleSchool   Father           55                74
# 478      F  MiddleSchool   Father           30                17
# 479      F  MiddleSchool   Father           35                14
#
#      AnnouncementsView  Discussion ParentschoolSatisfaction  \
# 0                    2          20                     Good
# 1                    3          25                     Good
# 2                    0          30                      Bad
# 3                    5          35                      Bad
# 4                   12          50                      Bad
# ..                 ...         ...                      ...
# 475                  5           8                      Bad
# 476                 14          28                      Bad
# 477                 25          29                      Bad
# 478                 14          57                      Bad
# 479                 23          62                      Bad
#
#     StudentAbsenceDays Class
# 0              Under-7     M
# 1              Under-7     M
# 2              Above-7     L
# 3              Above-7     L
# 4              Above-7     M
# ..                 ...   ...
# 475            Above-7     L
# 476            Under-7     M
# 477            Under-7     M
# 478            Above-7     L
# 479            Above-7     L
#
# [480 rows x 10 columns]

# %%
#Dropping feature "Topic" on the basis of domain knowledge and high cardinality
#data.drop("Topic",axis=1,inplace=True)

# %%
data
# Out:
#     gender       StageID Relation  raisedhands  VisITedResources  \
# 0        M    lowerlevel   Father           15                16
# 1        M    lowerlevel   Father           20                20
# 2        M    lowerlevel   Father           10                 7
# 3        M    lowerlevel   Father           30                25
# 4        M    lowerlevel   Father           40                50
# ..     ...           ...      ...          ...               ...
# 475      F  MiddleSchool   Father            5                 4
# 476      F  MiddleSchool   Father           50                77
# 477      F  MiddleSchool   Father           55                74
# 478      F  MiddleSchool   Father           30                17
# 479      F  MiddleSchool   Father           35                14
#
#      AnnouncementsView  Discussion ParentschoolSatisfaction  \
# 0                    2          20                     Good
# 1                    3          25                     Good
# 2                    0          30                      Bad
# 3                    5          35                      Bad
# 4                   12          50                      Bad
# ..                 ...         ...                      ...
# 475                  5           8                      Bad
# 476                 14          28                      Bad
# 477                 25          29                      Bad
# 478                 14          57                      Bad
# 479                 23          62                      Bad
#
#     StudentAbsenceDays Class
# 0              Under-7     M
# 1              Under-7     M
# 2              Above-7     L
# 3              Above-7     L
# 4              Above-7     M
# ..                 ...   ...
# 475            Above-7     L
# 476            Under-7     M
# 477            Under-7     M
# 478            Above-7     L
# 479            Above-7     L
#
# [480 rows x 10 columns]

# %% [markdown]
# # EDA

# %%
data.dtypes
# Out:
# gender                      object
# StageID                     object
# Relation                    object
# raisedhands                  int64
# VisITedResources             int64
# AnnouncementsView            int64
# Discussion                   int64
# ParentschoolSatisfaction    object
# StudentAbsenceDays          object
# Class                       object
# dtype: object

# %%
# Histogram helps to understand frequency distribution of single continous features
data.hist(figsize=(15,7));

# %%
data.columns
# Out:
# Index(['gender', 'StageID', 'Relation', 'raisedhands', 'VisITedResources',
#        'AnnouncementsView', 'Discussion', 'ParentschoolSatisfaction',
#        'StudentAbsenceDays', 'Class'],
#       dtype='object')

# %%
features = ["raisedhands","VisITedResources","AnnouncementsView","Discussion"]

# %%
sns.pairplot(x_vars = features,y_vars=features,data=data);

# %%
sns.pairplot(x_vars = features,y_vars=features,data=data,hue="Class");

# %%
# Visualizaation of catagorical data
sns.countplot(data=data,x="gender",hue="Class",palette="viridis");

# %%
# Visualizaation of catagorical data
sns.countplot(data=data,x="Relation",hue="Class",palette="Set1");

# %%
# Visualizaation of catagorical data
sns.countplot(data=data,x="StudentAbsenceDays",hue="Class",palette="pastel");

# %%
data.Class.value_counts()
# Out:
# Class
# M    211
# H    142
# L    127
# Name: count, dtype: int64

# %%
import warnings
warnings.filterwarnings("ignore")
sns.countplot(data=data,x="Class",palette = "pastel");

# %%
colname=[]
for x in data.columns:
    if data [x].dtypes=="object":
        colname.append(x)
colname
# Out:
# ['gender',
#  'StageID',
#  'Relation',
#  'ParentschoolSatisfaction',
#  'StudentAbsenceDays',
#  'Class']

# %%
# for preprocessing the data
from sklearn.preprocessing import LabelEncoder

le=LabelEncoder()

for x in colname[:-1]:
    data[x]=le.fit_transform(data[x])

    le_name_mapping = dict(zip(le.classes_, le.transform(le.classes_)))
    print("Feature", x)
    print("mapping", le_name_mapping)
    print("-------------------------")
# Out:
# Feature gender
# mapping {'F': np.int64(0), 'M': np.int64(1)}
# -------------------------
# Feature StageID
# mapping {'HighSchool': np.int64(0), 'MiddleSchool': np.int64(1), 'lowerlevel': np.int64(2)}
# -------------------------
# Feature Relation
# mapping {'Father': np.int64(0), 'Mum': np.int64(1)}
# -------------------------
# Feature ParentschoolSatisfaction
# mapping {'Bad': np.int64(0), 'Good': np.int64(1)}
# -------------------------
# Feature StudentAbsenceDays
# mapping {'Above-7': np.int64(0), 'Under-7': np.int64(1)}
# -------------------------

# %%
data
# Out:
#      gender  StageID  Relation  raisedhands  VisITedResources  \
# 0         1        2         0           15                16
# 1         1        2         0           20                20
# 2         1        2         0           10                 7
# 3         1        2         0           30                25
# 4         1        2         0           40                50
# ..      ...      ...       ...          ...               ...
# 475       0        1         0            5                 4
# 476       0        1         0           50                77
# 477       0        1         0           55                74
# 478       0        1         0           30                17
# 479       0        1         0           35                14
#
#      AnnouncementsView  Discussion  ParentschoolSatisfaction  \
# 0                    2          20                         1
# 1                    3          25                         1
# 2                    0          30                         0
# 3                    5          35                         0
# 4                   12          50                         0
# ..                 ...         ...                       ...
# 475                  5           8                         0
# 476                 14          28                         0
# 477                 25          29                         0
# 478                 14          57                         0
# 479                 23          62                         0
#
#      StudentAbsenceDays Class
# 0                     1     M
# 1                     1     M
# 2                     0     L
# 3                     0     L
# 4                     0     M
# ..                  ...   ...
# 475                   0     L
# 476                   1     M
# 477                   1     M
# 478                   0     L
# 479                   0     L
#
# [480 rows x 10 columns]

# %%
data.Class.unique()
# Out:
# array(['M', 'L', 'H'], dtype=object)

# %%
# Class follow on ordinary approach for classes so we will try to ncode it manuallyS
data["Class"] = data["Class"].map({"L":0,"M":1,"H":2})

# %%
data
# Out:
#      gender  StageID  Relation  raisedhands  VisITedResources  \
# 0         1        2         0           15                16
# 1         1        2         0           20                20
# 2         1        2         0           10                 7
# 3         1        2         0           30                25
# 4         1        2         0           40                50
# ..      ...      ...       ...          ...               ...
# 475       0        1         0            5                 4
# 476       0        1         0           50                77
# 477       0        1         0           55                74
# 478       0        1         0           30                17
# 479       0        1         0           35                14
#
#      AnnouncementsView  Discussion  ParentschoolSatisfaction  \
# 0                    2          20                         1
# 1                    3          25                         1
# 2                    0          30                         0
# 3                    5          35                         0
# 4                   12          50                         0
# ..                 ...         ...                       ...
# 475                  5           8                         0
# 476                 14          28                         0
# 477                 25          29                         0
# 478                 14          57                         0
# 479                 23          62                         0
#
#      StudentAbsenceDays  Class
# 0                     1      1
# 1                     1      1
# 2                     0      0
# 3                     0      0
# 4                     0      1
# ..                  ...    ...
# 475                   0      0
# 476                   1      1
# 477                   1      1
# 478                   0      0
# 479                   0      0
#
# [480 rows x 10 columns]

# %%
sns.set()
Class_plot=data["Class"].value_counts().plot(kind="bar")
plt.xlabel("Performance")
plt.ylabel("Count")
plt.xticks(rotation=360)
plt.show()

# %%
data["Class"].value_counts().plot(kind="pie",autopct="%.2f%%")
plt.ylabel(" ")
# Out:
# Text(0, 0.5, ' ')

# %%
X = data.values[:,0:-1] # 0 to-2
Y = data.values[:,-1]

# %%
print(X.shape)
print(Y.shape)
# Out:
# (480, 9)
# (480,)

# %%
from sklearn.model_selection import train_test_split

# split the data into test and train
X_train , X_test , Y_train , Y_test = train_test_split(X, Y, test_size=0.2,
                                                       random_state=10)

# %%
print(X_train.shape)
print(Y_train.shape)
print(X_test.shape)
print(Y_test.shape)
# Out:
# (384, 9)
# (384,)
# (96, 9)
# (96,)

# %%
from sklearn.linear_model import LogisticRegression
#create a model
classifier=LogisticRegression()
#fitting training data to the model
classifier.fit(X_train,Y_train)

Y_pred=classifier.predict(X_test)
print(Y_pred)
# Out:
# [2 1 1 0 2 2 2 2 1 0 1 1 1 1 1 2 0 2 1 1 0 1 0 2 1 0 2 1 1 2 1 2 0 1 1 0 1
#  1 0 2 1 0 1 0 2 2 2 1 1 1 1 1 2 1 1 1 2 0 1 2 2 0 2 1 1 1 1 2 0 2 1 0 1 2
#  1 1 0 0 1 2 1 2 0 0 1 2 1 2 2 1 2 0 1 1 2 1]

# %%
np.set_printoptions(suppress= True)
Y_pred_prob=classifier.predict_proba(X_test)
Y_pred_prob
# Out:
# array([[0.00761268, 0.42840499, 0.56398232],
#        [0.02376443, 0.78996776, 0.18626781],
#        [0.04026176, 0.84653971, 0.11319854],
#        [0.59581567, 0.37935384, 0.02483049],
#        [0.05078835, 0.46327922, 0.48593243],
#        [0.00027277, 0.18038024, 0.81934699],
#        [0.00165337, 0.35814771, 0.64019892],
#        [0.00316616, 0.36207288, 0.63476096],
#        [0.42752616, 0.53402526, 0.03844858],
#        [0.82950925, 0.16536407, 0.00512669],
#        [0.00369049, 0.60437229, 0.39193723],
#        [0.14860191, 0.76965261, 0.08174548],
#        [0.03178106, 0.52169904, 0.4465199 ],
#        [0.03222674, 0.6574584 , 0.31031486],
#        [0.03100439, 0.53384998, 0.43514562],
#        [0.00144265, 0.33874943, 0.65980793],
#        [0.96685395, 0.03221655, 0.00092951],
#        [0.00068725, 0.2653831 , 0.73392965],
#        [0.01405652, 0.70501284, 0.28093065],
#        [0.01958215, 0.74818532, 0.23223253],
#        [0.79204382, 0.19910283, 0.00885335],
#        [0.00328391, 0.71622305, 0.28049304],
#        [0.5942215 , 0.37521451, 0.03056399],
#        [0.00033915, 0.45239784, 0.54726301],
#        [0.00248358, 0.75389013, 0.24362629],
#        [0.94250904, 0.05608459, 0.00140637],
#        [0.00061609, 0.25725357, 0.74213033],
#        [0.00947301, 0.56444322, 0.42608377],
#        [0.01113459, 0.8535809 , 0.13528452],
#        [0.00007369, 0.17178685, 0.82813946],
#        [0.00328918, 0.64916053, 0.34755029],
#        [0.00202231, 0.33103169, 0.66694599],
#        [0.8426777 , 0.15100775, 0.00631455],
#        [0.0019136 , 0.54325603, 0.45483037],
#        [0.01471248, 0.74153624, 0.24375128],
#        [0.89189235, 0.10302075, 0.0050869 ],
#        [0.00308255, 0.59944793, 0.39746952],
#        [0.10786917, 0.69395116, 0.19817967],
#        [0.78255557, 0.20510125, 0.01234318],
#        [0.00099055, 0.19818498, 0.80082447],
#        [0.00253746, 0.76051344, 0.2369491 ],
#        [0.87667221, 0.11715136, 0.00617643],
#        [0.05396069, 0.49824448, 0.44779483],
#        [0.53483388, 0.4309242 , 0.03424193],
#        [0.01411058, 0.45950359, 0.52638583],
#        [0.00021204, 0.43289533, 0.56689263],
#        [0.0004794 , 0.21714058, 0.78238002],
#        [0.00397626, 0.68508253, 0.31094121],
#        [0.08307032, 0.71180405, 0.20512563],
#        [0.00418728, 0.58826289, 0.40754983],
#        [0.03214008, 0.55771136, 0.41014856],
#        [0.40246711, 0.48746198, 0.11007092],
#        [0.00680018, 0.37837798, 0.61482184],
#        [0.08274861, 0.82097397, 0.09627742],
#        [0.02785475, 0.7590237 , 0.21312155],
#        [0.0002628 , 0.51093075, 0.48880644],
#        [0.00010319, 0.19372739, 0.80616941],
#        [0.94329317, 0.05486425, 0.00184258],
#        [0.00591672, 0.69413868, 0.29994461],
#        [0.0000597 , 0.16099402, 0.83894629],
#        [0.00080058, 0.33838451, 0.66081491],
#        [0.90527596, 0.09011928, 0.00460476],
#        [0.00144355, 0.30543731, 0.69311914],
#        [0.05183201, 0.84856514, 0.09960286],
#        [0.48927238, 0.491201  , 0.01952663],
#        [0.04312315, 0.55968287, 0.39719398],
#        [0.08143302, 0.69115139, 0.22741559],
#        [0.00004231, 0.38391254, 0.61604515],
#        [0.71457782, 0.22499315, 0.06042903],
#        [0.00009094, 0.13062621, 0.86928285],
#        [0.08745267, 0.78937887, 0.12316846],
#        [0.68686828, 0.29661323, 0.01651848],
#        [0.2424712 , 0.66871452, 0.08881428],
#        [0.00635842, 0.42286438, 0.5707772 ],
#        [0.00614876, 0.65232787, 0.34152337],
#        [0.00671183, 0.64000602, 0.35328215],
#        [0.65183272, 0.29588113, 0.05228615],
#        [0.95111535, 0.04752564, 0.00135902],
#        [0.00067295, 0.59340919, 0.40591787],
#        [0.00011576, 0.20946549, 0.79041875],
#        [0.40177788, 0.53985547, 0.05836664],
#        [0.00005832, 0.17296266, 0.82697902],
#        [0.91457928, 0.08237247, 0.00304826],
#        [0.877088  , 0.11826716, 0.00464484],
#        [0.40332859, 0.51278677, 0.08388463],
#        [0.0009232 , 0.34542938, 0.65364742],
#        [0.17983927, 0.73522003, 0.0849407 ],
#        [0.00109138, 0.29951728, 0.69939134],
#        [0.00451609, 0.25890506, 0.73657885],
#        [0.04565374, 0.55949914, 0.39484711],
#        [0.00113505, 0.35786584, 0.64099912],
#        [0.84796037, 0.14646268, 0.00557694],
#        [0.26871381, 0.69244219, 0.038844  ],
#        [0.11648509, 0.77046477, 0.11305014],
#        [0.00027465, 0.2114076 , 0.78831775],
#        [0.02973481, 0.63149472, 0.33877047]])

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report

cfm=confusion_matrix(Y_test,Y_pred)
sns.heatmap(cfm, annot=True, fmt='g', cbar=False, cmap='BuPu')
plt.xlabel('Predicted Values')
plt.ylabel('Actual Values')
plt.show()


print("Classification report:")

print(classification_report(Y_test,Y_pred))

acc=accuracy_score(Y_test,Y_pred)
print("Accuracy of the model: ",acc)
# Out:
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.90      0.78      0.84        23
#            1       0.76      0.70      0.73        50
#            2       0.57      0.74      0.64        23
#
#     accuracy                           0.73        96
#    macro avg       0.74      0.74      0.74        96
# weighted avg       0.75      0.73      0.73        96
#
# Accuracy of the model:  0.7291666666666666

# %%
#predicting using the Decision_Tree_Classifier
from sklearn.tree import DecisionTreeClassifier

model_DecisionTree = DecisionTreeClassifier(criterion="gini",random_state=10)

#fit the model on the data and predict the values
model_DecisionTree.fit(X_train,Y_train)

Y_pred = model_DecisionTree.predict(X_test)
#print(Y_pred)
#print(list(zip(Y_test,Y_pred)))

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report

cfm=confusion_matrix(Y_test,Y_pred)
sns.heatmap(cfm, annot=True, fmt='g', cbar=False, cmap='BuPu')
plt.xlabel('Predicted Values')
plt.ylabel('Actual Values')
plt.show()


print("Classification report:")

print(classification_report(Y_test,Y_pred))

acc=accuracy_score(Y_test,Y_pred)
print("Accuracy of the model: ",acc)
# Out:
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.75      0.78      0.77        23
#            1       0.83      0.60      0.70        50
#            2       0.61      0.96      0.75        23
#
#     accuracy                           0.73        96
#    macro avg       0.73      0.78      0.74        96
# weighted avg       0.76      0.73      0.73        96
#
# Accuracy of the model:  0.7291666666666666

# %%
model_DecisionTree.score(X_train,Y_train)
# Out:
# 0.9973958333333334

# %%
# print the scores on training and test set
print('Training set score: {:.4f}'.format(model_DecisionTree.score(X_train, Y_train)))

print('Test set score: {:.4f}'.format(model_DecisionTree.score(X_test, Y_test)))
# Out:
# Training set score: 0.9974
# Test set score: 0.7292

# %%
print(list(zip(data.columns[:],model_DecisionTree.feature_importances_)))
# Out:
# [('gender', np.float64(0.04659080790408169)), ('StageID', np.float64(0.04475200367782753)), ('Relation', np.float64(0.03782980354869803)), ('raisedhands', np.float64(0.14128705922993948)), ('VisITedResources', np.float64(0.24978949957398358)), ('AnnouncementsView', np.float64(0.15716733396986007)), ('Discussion', np.float64(0.0922586971116643)), ('ParentschoolSatisfaction', np.float64(0.014873042610268889)), ('StudentAbsenceDays', np.float64(0.21545175237367642))]

# %%
sample = pd.DataFrame()

sample["Column"]=data.columns[0:-1]
sample["Imp value"]=model_DecisionTree.feature_importances_

sample.sort_values("Imp value",ascending=False)
# Out:
#                      Column  Imp value
# 4          VisITedResources   0.249789
# 8        StudentAbsenceDays   0.215452
# 5         AnnouncementsView   0.157167
# 3               raisedhands   0.141287
# 6                Discussion   0.092259
# 0                    gender   0.046591
# 1                   StageID   0.044752
# 2                  Relation   0.037830
# 7  ParentschoolSatisfaction   0.014873

# %%
plt.figure(figsize=(30,20))

from sklearn import tree

tree.plot_tree(model_DecisionTree.fit(X_train, Y_train));

# %%
from sklearn import tree
with open(r"model_DecisionTree.txt","w") as f:

    f = tree.export_graphviz(model_DecisionTree, feature_names=data.columns[0:-1],
                             out_file=f)

# %%
import  os 
os.getcwd()
# Out:
# 'C:\\Users\\Omkar Pawar\\OneDrive\\Desktop'

# %%
### Utilizing results from feature importance for the model tuning
data_new=data.drop(['StageID','ParentschoolSatisfaction'],axis=1)
data_new
# Out:
#      gender  Relation  raisedhands  VisITedResources  AnnouncementsView  \
# 0         1         0           15                16                  2
# 1         1         0           20                20                  3
# 2         1         0           10                 7                  0
# 3         1         0           30                25                  5
# 4         1         0           40                50                 12
# ..      ...       ...          ...               ...                ...
# 475       0         0            5                 4                  5
# 476       0         0           50                77                 14
# 477       0         0           55                74                 25
# 478       0         0           30                17                 14
# 479       0         0           35                14                 23
#
#      Discussion  StudentAbsenceDays  Class
# 0            20                   1      1
# 1            25                   1      1
# 2            30                   0      0
# 3            35                   0      0
# 4            50                   0      1
# ..          ...                 ...    ...
# 475           8                   0      0
# 476          28                   1      1
# 477          29                   1      1
# 478          57                   0      0
# 479          62                   0      0
#
# [480 rows x 8 columns]
